# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df2014 = pd.read_csv('finance_data/2014_Financial_Data.csv')
df2015 = pd.read_csv('finance_data/2015_Financial_Data.csv')
df2016 = pd.read_csv('finance_data/2016_Financial_Data.csv')
df2017 = pd.read_csv('finance_data/2017_Financial_Data.csv')
df2018 = pd.read_csv('finance_data/2018_Financial_Data.csv')

# %%
df2014.head()
# Out:
#   Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0         PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1       VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2         KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3        RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4        GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
#
#    R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# 2  0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# 3  0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
#
#    Interest Expense  ...  Receivables growth  Inventory Growth  Asset Growth  \
# ...

# %%
df2014.isnull().sum()
# Out:
# Unnamed: 0                0
# Revenue                  44
# Revenue Growth          236
# Cost of Revenue          74
# Gross Profit             52
#                        ...
# R&D Expense Growth      247
# SG&A Expenses Growth    243
# Sector                    0
# 2015 PRICE VAR [%]        0
# Class                     0
# Length: 225, dtype: int64

# %%
df2014.fillna(0 , inplace =True)
df2015.fillna(0 , inplace =True)
df2016.fillna(0 , inplace =True)
df2017.fillna(0 , inplace =True)
df2018.fillna(0 , inplace =True)
df2018.isnull().sum()
# Out:
# name                    0
# Revenue                 0
# Revenue Growth          0
# Cost of Revenue         0
# Gross Profit            0
#                        ..
# R&D Expense Growth      0
# SG&A Expenses Growth    0
# Sector                  0
# 2019 PRICE VAR [%]      0
# Class                   0
# Length: 225, dtype: int64

# %%
df2014.rename(columns={df2014.columns[0] : 'name'} , inplace = True)
df2015.rename(columns={df2015.columns[0] : 'name'} , inplace = True)
df2016.rename(columns={df2016.columns[0] : 'name'} , inplace = True)
df2017.rename(columns={df2017.columns[0] : 'name'} , inplace = True)
df2018.rename(columns={df2018.columns[0] : 'name'} , inplace = True)

# %%
df2018['name'].unique()
df2018.shape
# Out:
# (4392, 225)

# %%
dfall4= pd.merge(df2014,df2015 , on ='name' , how='inner')
dfall4.head()
# Out:
#    name     Revenue_x  Revenue Growth_x  Cost of Revenue_x  Gross Profit_x  \
# 0    PG  7.440100e+10           -0.0713       3.903000e+10    3.537100e+10
# 1  VIPS  3.734148e+09            1.1737       2.805625e+09    9.285226e+08
# 2    KR  9.837500e+10            0.0182       7.813800e+10    2.023700e+10
# 3   RAD  2.552641e+10            0.0053       1.820268e+10    7.323734e+09
# 4   GIS  1.790960e+10            0.0076       1.153980e+10    6.369800e+09
#
#    R&D Expenses_x  SG&A Expense_x  Operating Expenses_x  Operating Income_x  \
# 0    0.000000e+00    2.146100e+10          2.146100e+10        1.391000e+10
# 1    1.083303e+08    3.441414e+08          7.939267e+08        1.345959e+08
# 2    0.000000e+00    1.519600e+10          1.751200e+10        2.725000e+09
# 3    0.000000e+00    6.561162e+09          6.586482e+09        7.372520e+08
# 4    0.000000e+00    3.474300e+09          3.412400e+09        2.957400e+09
#
# ...

# %%
dfall = pd.concat([df2014,df2015,df2016,df2017,df2018])
dfall.shape
# Out:
# (22077, 229)

# %%
dfall.fillna(0,inplace=True)
dfall.isnull().sum()
# Out:
# Unnamed: 0            0
# Revenue               0
# Revenue Growth        0
# Cost of Revenue       0
# Gross Profit          0
#                      ..
# Class                 0
# 2016 PRICE VAR [%]    0
# 2017 PRICE VAR [%]    0
# 2018 PRICE VAR [%]    0
# 2019 PRICE VAR [%]    0
# Length: 229, dtype: int64

# %%
years =[2014,2015,2016,2017,2018]
quickratio_year= list([0,0,0,0,0])
i = 0
for y  in years :
   quickratio_year[i] = dfall.groupby(f'{y} PRICE VAR [%]')
   i+=1

quickratio_year[0]

plt.figure(figsize=(10,10))
y= dfall['quickRatio']
x= years
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 5
#       3 i = 0
#       4 for y  in years :
# ----> 5    quickratio_year[i] = dfall.groupby(f'{y} PRICE VAR [%]')
#       6    i+=1
#       8 quickratio_year[0]
#
# File c:\miniconda\envs\python_ml\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
y=2016
h=list([0,0,0,0])
h[0] =dfall.groupby(f'{y} PRICE VAR [%]')
#h[0].head(3)
yy=2017
h[1] =dfall.groupby(f'{yy} PRICE VAR [%]')
h[1].head(3)
# Out:
#      Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0            PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1          VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2            KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 0            PG  6.529900e+10         -0.0770     3.290900e+10  3.239000e+10
# 1          VIPS  8.148496e+09          0.3156     6.190740e+09  1.957756e+09
# ...         ...           ...             ...              ...           ...
# 4792       TSRI  6.099828e+07          0.0626     5.103888e+07  9.959402e+06
# 4793       TZOO  1.142630e+08         -0.0782     1.385500e+07  1.004080e+08
# 4794      USATP  7.700000e+07          0.0000     5.500000e+07  2.200000e+07
# 4795       WSTG  1.646090e+08         -0.5692     1.372780e+08  2.733100e+07
# 4796        WTT  3.132700e+07         -0.0538     1.816500e+07  1.316200e+07
#
# ...

# %%
dfall.groupby('2016 PRICE VAR [%]').head(3)
# Out:
#      Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0            PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1          VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2            KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 0            PG  7.074900e+10         -0.0491     3.705600e+10  3.369300e+10
# 1          VIPS  6.193685e+09          0.6587     4.669038e+09  1.524648e+09
# ...         ...           ...             ...              ...           ...
# 4115       TSRI  5.740290e+07          0.1590     4.808743e+07  9.315468e+06
# 4116       TZOO  1.239610e+08         -0.1911     1.814800e+07  1.058130e+08
# 4117      USATP  5.800000e+07          0.0000     4.100000e+07  1.700000e+07
# 4118       WSTG  3.820900e+08          0.1213     3.555170e+08  2.657300e+07
# 4119        WTT  3.310911e+07         -0.1792     1.828123e+07  1.482787e+07
#
# ...

# %%
dfall['Year'] = pd.to_datetime(dfall[''])
